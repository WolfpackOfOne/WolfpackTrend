# %% [markdown]
# # Scaling Adherence
#
# Compare expected scale path (`scheduled_w`) vs realized path (`actual_w`) from `targets.csv`.
#
# Output:
# - Progress gap by tier (`actual_progress - planned_progress`)
# - Planned vs actual by day-in-week

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from io import StringIO
from IPython.display import display

pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (14, 6)

from QuantConnect import *
from QuantConnect.Research import QuantBook
from config import TEAM_ID

qb = QuantBook()
print('QuantBook initialized')


def read_csv_from_store(key):
    try:
        if not qb.ObjectStore.ContainsKey(key):
            print(f'ObjectStore key not found: {key}')
            return None
        content = qb.ObjectStore.Read(key)
        if not content:
            print(f'Empty ObjectStore key: {key}')
            return None
        return pd.read_csv(StringIO(content))
    except Exception as e:
        print(f'Error reading {key}: {e}')
        return None

# %% [markdown]
# ## Data Loading & Progress Metric Computation
#
# Loads `targets.csv` and optionally `signals.csv`, then computes planned versus actual progress through the weekly scaling schedule as a fraction from 0 to 1. The signal tier is inferred from logged magnitude so planned and actual progress can be compared separately for strong, moderate, and weak scaling curves. The head preview shows the key columns — `planned_progress`, `actual_progress`, and `progress_gap` — for the first few rows.

# %% [markdown]
# ## Progress Gap Boxplot and Planned vs Actual Profiles
#
# These three charts test whether actual execution tracks the front-loaded scaling schedule by tier. The left boxplot shows the distribution of `actual - planned` progress per tier — positive gaps mean ahead of schedule, negative mean behind. The two line charts on the right overlay mean planned and actual progress by day-in-week for each tier, visually confirming whether strong-tier positions scale faster than weak-tier ones as designed.

# %% [markdown]
# ## Most Lagging Symbols Table
#
# This table ranks symbols by their average progress gap, with the most negative values at the top indicating names that consistently lag the planned scaling schedule. Chronic laggards are often less liquid stocks where limit orders at the tier-specific offset are harder to fill within a single day. Identifying these symbols helps calibrate whether to widen their limit offsets or increase the stale-limit cancellation tolerance.

# %%
df_targets = read_csv_from_store(f'{TEAM_ID}/targets.csv')
df_signals = read_csv_from_store(f'{TEAM_ID}/signals.csv')

if df_targets is None:
    raise ValueError('targets.csv is required.')

df_targets['date'] = pd.to_datetime(df_targets['date'])
for col in ['start_w', 'weekly_target_w', 'scheduled_w', 'actual_w', 'scale_day']:
    df_targets[col] = pd.to_numeric(df_targets[col], errors='coerce').fillna(0.0)

# Merge signals using merge_asof: find the most recent signal per symbol
# on or before each rebalance date (week_id in targets)
if df_signals is not None:
    df_signals['date'] = pd.to_datetime(df_signals['date'])
    df_signals['magnitude'] = pd.to_numeric(df_signals['magnitude'], errors='coerce').fillna(0.0).abs()
    df_signals = df_signals.sort_values('date')

    # Get unique (week_id, symbol) pairs from targets with parsed rebalance date
    rebal_keys = (
        df_targets[['week_id', 'symbol']].drop_duplicates()
        .assign(rebal_date=lambda d: pd.to_datetime(d['week_id']))
        .sort_values('rebal_date')
    )

    # Find most recent signal for each symbol on or before the rebalance date
    sig_matched = pd.merge_asof(
        rebal_keys,
        df_signals[['date', 'symbol', 'magnitude']].rename(columns={'date': 'signal_date'}),
        left_on='rebal_date',
        right_on='signal_date',
        by='symbol',
        direction='backward'
    )

    df = df_targets.merge(
        sig_matched[['week_id', 'symbol', 'magnitude']],
        on=['week_id', 'symbol'],
        how='left'
    )
else:
    df = df_targets.copy()
    df['magnitude'] = np.nan

def tier_from_row(row):
    m = row['magnitude']
    # Label exits: target weight is zero (or near-zero) while start weight is not
    if pd.isna(m) and abs(row['weekly_target_w']) < 1e-10 and abs(row['start_w']) > 1e-10:
        return 'exit'
    if pd.isna(m):
        return 'unknown'
    if m >= 0.7:
        return 'strong'
    if m >= 0.3:
        return 'moderate'
    return 'weak'

df['tier'] = df.apply(tier_from_row, axis=1)
df['total_week_order_abs'] = (df['weekly_target_w'] - df['start_w']).abs()
df['planned_progress'] = np.where(
    df['total_week_order_abs'] > 1e-10,
    (df['scheduled_w'] - df['start_w']).abs() / df['total_week_order_abs'],
    1.0
)
df['actual_progress'] = np.where(
    df['total_week_order_abs'] > 1e-10,
    (df['actual_w'] - df['start_w']).abs() / df['total_week_order_abs'],
    1.0
)
df['planned_progress'] = df['planned_progress'].clip(0, 1)
df['actual_progress'] = df['actual_progress'].clip(0, 1)
df['progress_gap'] = df['actual_progress'] - df['planned_progress']

df = df.sort_values(['week_id', 'symbol', 'date'])
df['day_in_week'] = df.groupby(['week_id', 'symbol']).cumcount()

# Show tier distribution to verify unknown is reduced
print(f"Tier distribution:\n{df['tier'].value_counts().to_string()}\n")
display(df[['date', 'week_id', 'symbol', 'tier', 'planned_progress', 'actual_progress', 'progress_gap']].head())

# %%
tier_order = [t for t in ['strong', 'moderate', 'weak', 'exit', 'unknown'] if t in df['tier'].unique()]

fig, ax = plt.subplots(figsize=(10, 5))
sns.boxplot(data=df, x='tier', y='progress_gap', order=tier_order, ax=ax)
ax.axhline(0, color='black', linewidth=1)
ax.set_title('Progress Gap by Signal Tier (Actual - Planned)')
ax.set_ylabel('Progress gap')
ax.set_xlabel('Tier')
ax.grid(alpha=0.2)
plt.tight_layout()
plt.show()

profile = (
    df.groupby(['tier', 'day_in_week'], as_index=False)
      .agg(planned=('planned_progress', 'mean'), actual=('actual_progress', 'mean'))
)

fig, axes = plt.subplots(1, 2, figsize=(16, 5), sharey=True)
sns.lineplot(data=profile, x='day_in_week', y='planned', hue='tier', marker='o', ax=axes[0])
axes[0].set_title('Planned Progress by Tier')
axes[0].set_xlabel('Day-in-week')
axes[0].set_ylabel('Progress')
axes[0].grid(alpha=0.3)

sns.lineplot(data=profile, x='day_in_week', y='actual', hue='tier', marker='o', ax=axes[1])
axes[1].set_title('Actual Progress by Tier')
axes[1].set_xlabel('Day-in-week')
axes[1].set_ylabel('Progress')
axes[1].grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %%
worst_lag = (
    df.groupby('symbol', as_index=False)['progress_gap']
      .mean()
      .sort_values('progress_gap')
)
print('Most negative average gap (lagging schedule):')
display(worst_lag.head(15))
